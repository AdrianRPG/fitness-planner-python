# %%
#The user provides their full name to run and display the greeting of the code.

username = input("Please enter your full name: ")
print("Hi", username, "! WELCOME TO MY GYM PROGRAM!")
ready_question = input("Are you ready?")
print("LET'S GO!")
TITLE = """
===========================================================================================================================================
                                                            GYM PROGRAM
                                                      Start Your New Lifestyle
===========================================================================================================================================
"""
print(TITLE)
INTRODUCTION = """
I am Adrian Renato Perez Galindo, and this is my first project for Computer Programming, using Python.
Before we begin, I would like to mention that I chose the "GYM" theme for my program because it is an
activity I personally enjoy and like to talk about. For this reason, I decided to create software that
uses different operators and functions to build a graphical user interface. In other words, it is a
program where I, as the developer, can provide information to users, allowing them to easily interact with it. 

With this brief introduction, we can begin this journey...
"""
print(INTRODUCTION)
print("Please, perform the following steps/options to make the evaluation in the best possible way.")
QUIT = '6'
NUMBERS = ('1', '2', '3', '4', '5', '6')
MENU = """
~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
////////////////MENU////////////////
~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
OPTIONS:
1) PERSONAL INFORMATION
2) QUESTIONS ABOUT THE USER HEALTH
3) QUESTIONS ABOUT THE USER EXPERIENCE
4) DETERMINE YOUR DIET AND GOALS
5) GET YOUR OWN ROUTINE
6) QUIT THE PROGRAM"""

def acceptOption():
    while True:
        option = input("Enter a number: ")
        if not option in NUMBERS:
            print("Error: Option not recognized. Check it out and try again!")
        else:
            return option
        
def runOption(option):
    """Selects and runs an option."""
    if option == '1':
        personalInformation()
    if option == '2':
        health_questions()
    if option == '3':
        experience_questions()
    if option == '4':
        diet_information()
    if option == '5':
        routine()
        
#Require and display information of the user
def personalInformation():
    """Require input of the user"""
    EXPLANATION_1 = """In this section, the program is requesting certain information from the user so that the user can identify himself throughout the process."""
    print(EXPLANATION_1)
    usergender = input("Enter your gender (Answer with 'Male' or 'Female'): ")
    while True:
        try:
            userage = int(input("Enter your Age: "))
        except ValueError:
            print("Your answer is not correct. Please, check it again and try to give a good answer")
            continue
        else:
            break
    if userage < 15:
        MESSAGE_1 = """
        Dear user,
            
        Unfortunately, we have to inform you that you are underage, so we, as experts and professionals in the field,
        do not believe that it is convenient for you to continue with the program, since it could not be beneficial 
        for your development and growth. That is why we recommend that before you can continue with the program, you
        consult with your parents or with the person who is in charge of you. Similarly, we recommend that you visit 
        your doctor to give you the endorsement to continue with this process. We hope you understand. 
        Thank you very much for visiting us, we look forward to your prompt response. Thank you!"""
        print(MESSAGE_1)
        exit()
    if userage > 65:
        MESSAGE_2 = """
        Dear user,
            
        Unfortunately, we have to inform you that you are elderly, so we, as experts and professionals on the subject,
        do not believe that it is convenient for you to continue with the program, since it could be dangerous or 
        counterproductive for your health. That is why we recommend that before you can continue with the program, 
        visit your doctor so he/she can give you the endorsement to continue with this process. We hope you understand. 
        Thank you very much for visiting us, we look forward to your prompt response. Thank you!"""
        print(MESSAGE_2)
        exit()
    height = input("Enter your height (foot): ")
    print(" ")
    print(" ")
    print("--------------------")
    print("PERSONAL INFORMATION")
    print("--------------------")
    print("Name: ", username)
    print("Gender: ", usergender)
    print("Age: ", userage)
    print("Height: ", height)

def health_questions():
    EXPLANATION_2 = """
    In this section, the program and our experts only require certain information regarding the health and restrictions that the user may have, in order to continue the program satisfactorily."""
    print(EXPLANATION_2)
    print("Please answer with 'Yes' or 'No'. Also, be totally honest so our professionals experts will be able to provide you with a good evaluation")
    question_1 = input("1.- Are you allergic to any food or supplement?")
    question_2 = input("2.- Do you suffer from any disease ?")
    question_3 = input("3.- Do you have or have you had an injury?")
    BADNEWS = """
    Bad news. We do not believe that it is the most appropriate and safe for you to continue completing these forms
    if you suffer from any illness or have an injury. We believe that the best thing would be for you to consult a 
    trusted doctor or physician, who can provide you with support specifying that you can perform physical activity 
    without any problem. But in the end, it is up to you."""
    GOODNEWS = """
    Good News. You are totally healthy and free of risks to be able to start doing physical activity without any inconvenience."""
    if question_2 == "Yes" or question_2 == "yes":
        if question_3 == "Yes" or question_3 == "yes":
            print(BADNEWS)
        if question_3 == "No" or question_3 == "no":
            print(BADNEWS)
    elif question_2 == "No" or question_2 == "no":
        if question_3 == "No" or question_3 == "no":
            print(GOODNEWS)
        if question_3 == "Yes" or question_3 == "yes":
            print(BADNEWS)
    else:
        print("REMEMBER: Answer with 'Yes' or 'No'. Please Check out your answers and try to response again.")
        health_questions()
        
def experience_questions():
    EXPLANATION_3 = """
    In this section, the interface requires some information from the user to take it into account and then provide the appropriate options during the process."""
    print("EXPLANATION_3")
    print("Please answer honestly so that our professional experts can give you a good evaluation.")
    question_4 = input("1.- Do you use supplements? If so, which ones? (Specify with the Name of Supplement and Purpose of Use)")
    question_5 = input("2.- Have you ever trained at home or in the gym?")
    
def diet_information():
    DEFINITIONS = """
    In this section, we would like you to please specify what is your goal or desired stage to achieve with this program. 
    For this, for those who do not have knowledge of the subject, the following definitions will be provided to give a greater 
    understanding and information of the subject:
    
        - Body Recomposition: It is the process by which it is possible to successfully achieve 
        two stages at the same time, gain muscle mass while losing fat. This can happen under 
        conditions of proper eating plan, effective exercise plan and sufficient rest.
        -  Muscular Definition: It is the phase that reduces fat as much as possible to better 
        preserve maximum muscle mass. A classic diet helps to get rid of fat, but at the same time, 
        a certain amount of muscle mass can be lost. The goal is to preserve the muscles, therefore 
        a well-adapted diet, adequate training sessions, and sufficient dietary supplements must be followed.
        - Muscle Volume (Bulking): It is the phase in which we try to gain as much muscle mass as possible while minimizing 
        as much as possible the fat gain that can be caused during this weight gain.
    """
    print(DEFINITIONS)
    EXPLANATION_4 = """
    Next, one of the most important sections of this program will be developed, since it will provide users 
    with the necessary and essential information for the development of their physical change. Basically, the 
    total calories that the user should consume will be calculated, including the amount of protein, carbohydrates 
    and natural fats. Before that, a study will be carried out and a hypothesis will be established for the 
    user's situation, so finally the user will be able to answer the following questions in the best possible way:"""
    print(EXPLANATION_4)
    print("Please answer the following requirements correctly and try to be as exact as possible, by this I mean that you use integer numbers. ")
    weight = int(input("Enter your weight (lbs): "))
    question_6 = input("Determine how active you are on a day-to-day basis (Answer with the following options: 'S' for Sedentary, 'A' for Active and 'V' for Very active)")
    WARNING_1 = """
    WARNING: According to the data provided by you and our professional virtual nutritionists, 
    it can be determined that you should gain weight and perform the following STAGE:
        - Bulking
    It should be noted that this is only a recommendation. At the end of it all, the client, that is you, determines the objective."""
    WARNING_2 = """
    WARNING: According to the data provided by you and our professional virtual nutritionists, 
    it can be determined that you should lose weight and perform any of the following two STAGES:
        - Definition
        - Muscle Recomposition
    It should be noted that this is only a recommendation. At the end of it all, the client, that is you, determines the objective."""
    WARNING_3 = """
    Warning: According to the data provided by you and our professional virtual nutritionists, 
    it can be determined that you have the ideal weight in relation to your height and age, 
    so by recommendation of our experts, you can perform any of the following stages:
        - Muscle Recomposition
        - Definition
        - Bulking
    It should be noted that this is only a recommendation. At the end of everything, the client, that is you, determines the objective."""
    if weight < 140:
        print(WARNING_1)
    elif weight > 180:
        print(WARNING_2)
    else:
        print(WARNING_3)
    print(" ")
    question_7 = input("So according to the previous information, which of these options is your goal? (Answer with the following options: 'R' for Recomposition, 'D' for Definition and 'B' for Bulking)")
    status_variable = 0
    if question_6 == 'S' or question_6 == "s":
        if question_7 == 'R' or question_7 == 'r':
            status_variable = 14
            maintance_calories = weight * status_variable
            #formula to calculate the amount of protein (gr)
            amount_proteins = weight * 0.75
            #formula to calculate the amount of natural fats (gr)
            amount_fat = weight * 0.30
            #general formula to calculate the amount of carbohydrates (gr)
            protein_calories = amount_proteins * 4
            fat_calories = amount_fat * 9
            amount_calories_fat_protein = protein_calories + fat_calories
            carbohydrates_calories = maintance_calories - amount_calories_fat_protein
            amount_carbohydrate = carbohydrates_calories / 4
            print("|User Weight (lbs)|Amount of Proteins (gr)|Amount of Carbohydrate (gr)|Amount of Natural Fat (gr)|")
            nestedList = [[round(weight), round(amount_proteins), round(amount_carbohydrate), round(amount_fat)]]
            for item in nestedList:
                print("|", item[0], " " *(14 - len(str(item[0]))),"|",
                    item [1], " "*(20-len(str(item[1]))), "|",
                    item[2], " "*(24-len(str(item[2]))), "|",
                    item[3], " "*(23-len(str(item[3]))), "|")
            print("|Amount of Proteins (cal)|Amount of Carbohydrate (cal)|Amount of Natural Fat (cal)|Total Amount of Calories (cal)|")
            nestedList = [[protein_calories, carbohydrates_calories, fat_calories, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(21 - len(str(item[0]))),"|",
                    item [1], " "*(25-len(str(item[1]))), "|",
                    item[2], " "*(24-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
        if question_7 == 'D' or question_7 == 'd':
            status_variable = 14
            maintance_calories = (weight * status_variable) - 400
            #formula to calculate the amount of protein (gr)
            amount_proteins = weight * 0.75
            #formula to calculate the amount of natural fats (gr)
            amount_fat = weight * 0.30
            #general formula to calculate the amount of carbohydrates (gr)
            protein_calories = amount_proteins * 4
            fat_calories = amount_fat * 9
            amount_calories_fat_protein = protein_calories + fat_calories
            carbohydrates_calories = maintance_calories - amount_calories_fat_protein
            amount_carbohydrate = carbohydrates_calories / 4
            print("|Amount of Proteins (gr)|Amount of Carbohydrate (gr)|Amount of Natural Fat (gr)|Total Amount of Calories (cal)|")
            nestedList = [[amount_proteins, amount_carbohydrate, amount_fat, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(20 - len(str(item[0]))),"|",
                    item [1], " "*(24-len(str(item[1]))), "|",
                    item[2], " "*(23-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
            print("|Amount of Proteins (cal)|Amount of Carbohydrate (cal)|Amount of Natural Fat (cal)|Total Amount of Calories (cal)|")
            nestedList = [[protein_calories, carbohydrates_calories, fat_calories, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(21 - len(str(item[0]))),"|",
                    item [1], " "*(25-len(str(item[1]))), "|",
                    item[2], " "*(24-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
        if question_7 == 'B' or question_7 == 'b':
            status_variable = 14
            maintance_calories = (weight * status_variable) + 400
            #formula to calculate the amount of protein (gr)
            amount_proteins = weight * 0.75
            #formula to calculate the amount of natural fats (gr)
            amount_fat = weight * 0.30
            #general formula to calculate the amount of carbohydrates (gr)
            protein_calories = amount_proteins * 4
            fat_calories = amount_fat * 9
            amount_calories_fat_protein = protein_calories + fat_calories
            carbohydrates_calories = maintance_calories - amount_calories_fat_protein
            amount_carbohydrate = carbohydrates_calories / 4
            print("|Amount of Proteins (gr)|Amount of Carbohydrate (gr)|Amount of Natural Fat (gr)|Total Amount of Calories (cal)|")
            nestedList = [[amount_proteins, amount_carbohydrate, amount_fat, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(20 - len(str(item[0]))),"|",
                    item [1], " "*(24-len(str(item[1]))), "|",
                    item[2], " "*(23-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
            print("|Amount of Proteins (cal)|Amount of Carbohydrate (cal)|Amount of Natural Fat (cal)|Total Amount of Calories (cal)|")
            nestedList = [[protein_calories, carbohydrates_calories, fat_calories, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(21 - len(str(item[0]))),"|",
                    item [1], " "*(25-len(str(item[1]))), "|",
                    item[2], " "*(24-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
    if question_6 == 'A' or question_6 == 'a':
        if question_7 == 'R' or question_7 == 'r':
            status_variable = 15
            maintance_calories = (weight * status_variable)
            #formula to calculate the amount of protein (gr)
            amount_proteins = weight * 1.00
            #formula to calculate the amount of natural fats (gr)
            amount_fat = weight * 0.35
            #general formula to calculate the amount of carbohydrates (gr)
            protein_calories = amount_proteins * 4
            fat_calories = amount_fat * 9
            amount_calories_fat_protein = protein_calories + fat_calories
            carbohydrates_calories = maintance_calories - amount_calories_fat_protein
            amount_carbohydrate = carbohydrates_calories / 4
            print("|Amount of Proteins (gr)|Amount of Carbohydrate (gr)|Amount of Natural Fat (gr)|Total Amount of Calories (cal)|")
            nestedList = [[amount_proteins, amount_carbohydrate, amount_fat, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(20 - len(str(item[0]))),"|",
                    item [1], " "*(24-len(str(item[1]))), "|",
                    item[2], " "*(23-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
            print("|Amount of Proteins (cal)|Amount of Carbohydrate (cal)|Amount of Natural Fat (cal)|Total Amount of Calories (cal)|")
            nestedList = [[protein_calories, carbohydrates_calories, fat_calories, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(21 - len(str(item[0]))),"|",
                    item [1], " "*(25-len(str(item[1]))), "|",
                    item[2], " "*(24-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
        if question_7 == 'D' or question_7 == 'd':
            status_variable = 15
            maintance_calories = (weight * status_variable) - 400
            #formula to calculate the amount of protein (gr)
            amount_proteins = weight * 1.00
            #formula to calculate the amount of natural fats (gr)
            amount_fat = weight * 0.35
            #general formula to calculate the amount of carbohydrates (gr)
            protein_calories = amount_proteins * 4
            fat_calories = amount_fat * 9
            amount_calories_fat_protein = protein_calories + fat_calories
            carbohydrates_calories = maintance_calories - amount_calories_fat_protein
            amount_carbohydrate = carbohydrates_calories / 4
            print("|Amount of Proteins (gr)|Amount of Carbohydrate (gr)|Amount of Natural Fat (gr)|Total Amount of Calories (cal)|")
            nestedList = [[amount_proteins, amount_carbohydrate, amount_fat, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(20 - len(str(item[0]))),"|",
                    item [1], " "*(24-len(str(item[1]))), "|",
                    item[2], " "*(23-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
            print("|Amount of Proteins (cal)|Amount of Carbohydrate (cal)|Amount of Natural Fat (cal)|Total Amount of Calories (cal)|")
            nestedList = [[protein_calories, carbohydrates_calories, fat_calories, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(21 - len(str(item[0]))),"|",
                    item [1], " "*(25-len(str(item[1]))), "|",
                    item[2], " "*(24-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
        if question_7 == 'B' or question_7 == 'b':
            status_variable = 15
            maintance_calories = (weight * status_variable) + 400
            #formula to calculate the amount of protein (gr)
            amount_proteins = weight * 1.00
            #formula to calculate the amount of natural fats (gr)
            amount_fat = weight * 0.35
            #general formula to calculate the amount of carbohydrates (gr)
            protein_calories = amount_proteins * 4
            fat_calories = amount_fat * 9
            amount_calories_fat_protein = protein_calories + fat_calories
            carbohydrates_calories = maintance_calories - amount_calories_fat_protein
            amount_carbohydrate = carbohydrates_calories / 4
            print("|Amount of Proteins (gr)|Amount of Carbohydrate (gr)|Amount of Natural Fat (gr)|Total Amount of Calories (cal)|")
            nestedList = [[amount_proteins, amount_carbohydrate, amount_fat, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(20 - len(str(item[0]))),"|",
                    item [1], " "*(24-len(str(item[1]))), "|",
                    item[2], " "*(23-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
            print("|Amount of Proteins (cal)|Amount of Carbohydrate (cal)|Amount of Natural Fat (cal)|Total Amount of Calories (cal)|")
            nestedList = [[protein_calories, carbohydrates_calories, fat_calories, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(21 - len(str(item[0]))),"|",
                    item [1], " "*(25-len(str(item[1]))), "|",
                    item[2], " "*(24-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
    if question_6 == 'V' or question_6 == 'v':
        if question_7 == 'R' or question_7 == 'r':
            status_variable = 16
            maintance_calories = (weight * status_variable)
            #formula to calculate the amount of protein (gr)
            amount_proteins = weight * 1.25
            #formula to calculate the amount of natural fats (gr)
            amount_fat = weight * 0.40
            #general formula to calculate the amount of carbohydrates (gr)
            protein_calories = amount_proteins * 4
            fat_calories = amount_fat * 9
            amount_calories_fat_protein = protein_calories + fat_calories
            carbohydrates_calories = maintance_calories - amount_calories_fat_protein
            amount_carbohydrate = carbohydrates_calories / 4
            print("|Amount of Proteins (gr)|Amount of Carbohydrate (gr)|Amount of Natural Fat (gr)|Total Amount of Calories (cal)|")
            nestedList = [[amount_proteins, amount_carbohydrate, amount_fat, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(20 - len(str(item[0]))),"|",
                    item [1], " "*(24-len(str(item[1]))), "|",
                    item[2], " "*(23-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
            print("|Amount of Proteins (cal)|Amount of Carbohydrate (cal)|Amount of Natural Fat (cal)|Total Amount of Calories (cal)|")
            nestedList = [[protein_calories, carbohydrates_calories, fat_calories, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(21 - len(str(item[0]))),"|",
                    item [1], " "*(25-len(str(item[1]))), "|",
                    item[2], " "*(24-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
        if question_7 == 'D' or question_7 == 'd':
            status_variable = 16
            maintance_calories = (weight * status_variable) - 400
            #formula to calculate the amount of protein (gr)
            amount_proteins = weight * 1.25
            #formula to calculate the amount of natural fats (gr)
            amount_fat = weight * 0.40
            #general formula to calculate the amount of carbohydrates (gr)
            protein_calories = amount_proteins * 4
            fat_calories = amount_fat * 9
            amount_calories_fat_protein = protein_calories + fat_calories
            carbohydrates_calories = maintance_calories - amount_calories_fat_protein
            amount_carbohydrate = carbohydrates_calories / 4
            print("|Amount of Proteins (gr)|Amount of Carbohydrate (gr)|Amount of Natural Fat (gr)|Total Amount of Calories (cal)|")
            nestedList = [[amount_proteins, amount_carbohydrate, amount_fat, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(20 - len(str(item[0]))),"|",
                    item [1], " "*(24-len(str(item[1]))), "|",
                    item[2], " "*(23-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
            print("|Amount of Proteins (cal)|Amount of Carbohydrate (cal)|Amount of Natural Fat (cal)|Total Amount of Calories (cal)|")
            nestedList = [[protein_calories, carbohydrates_calories, fat_calories, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(21 - len(str(item[0]))),"|",
                    item [1], " "*(25-len(str(item[1]))), "|",
                    item[2], " "*(24-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
        if question_7 == 'B' or question_7 == 'b':
            status_variable = 16
            maintance_calories = (weight * status_variable) + 400
            #formula to calculate the amount of protein (gr)
            amount_proteins = weight * 1.25
            #formula to calculate the amount of natural fats (gr)
            amount_fat = weight * 0.40
            #general formula to calculate the amount of carbohydrates (gr)
            protein_calories = amount_proteins * 4
            fat_calories = amount_fat * 9
            amount_calories_fat_protein = protein_calories + fat_calories
            carbohydrates_calories = maintance_calories - amount_calories_fat_protein
            amount_carbohydrate = carbohydrates_calories / 4
            print("|Amount of Proteins (gr)|Amount of Carbohydrate (gr)|Amount of Natural Fat (gr)|Total Amount of Calories (cal)|")
            nestedList = [[amount_proteins, amount_carbohydrate, amount_fat, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(20 - len(str(item[0]))),"|",
                    item [1], " "*(24-len(str(item[1]))), "|",
                    item[2], " "*(23-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
            print("|Amount of Proteins (cal)|Amount of Carbohydrate (cal)|Amount of Natural Fat (cal)|Total Amount of Calories (cal)|")
            nestedList = [[protein_calories, carbohydrates_calories, fat_calories, maintance_calories]]
            for item in nestedList:
                print("|", item[0], " " *(21 - len(str(item[0]))),"|",
                    item [1], " "*(25-len(str(item[1]))), "|",
                    item[2], " "*(24-len(str(item[2]))), "|",
                    item[3], " "*(27-len(str(item[3]))), "|")
def routine():
    EXPLANATION_5 = """
    In this last section, certain information will be required from the user, since this will be essential and useful 
    to determine which routine to offer the user, so that this, in turn, is the most appropriate and effective during 
    the process. So, based on the information provided above and your experience and physical activity throughout your life,
    which of the following options do you think best describes you as an athlete?:
        - BEGINNER
        - INTERMEDIATE
        - ADVANCED
    """
    print(EXPLANATION_5)
    ROUTINE_1 = """
    -------------------------------------------------------------------------------------------------------------------------------
    |//////////////////////////////////////////////////////////GYM PROGRAM////////////////////////////////////////////////////////|
    -------------------------------------------------------------------------------------------------------------------------------
    |       MONDAY       |      TUESDAY       |      WEDNESDAY      |      THRUSDAY      |       FRIDAY       | SATURDAY | SUNDAY |      
    ------------------------------------------------------------------------------------------------------------------------------
    |  Incline Push Ups  |      Pull Ups      |       Squads        |      Bench Dips    |      Chin Ups      |   REST   |  REST  |
    | (3 sets X 10 reps) | (3 sets X 10 reps) | (3 sets X 12 reps)  | (3 sets X 10 reps) | (3 sets X 10 reps) |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------
    |  Decline Push Ups  |    Inverted Row    |   Forward Lunges    |      Push Ups      |     Bicep Curl     |   REST   |  REST  |
    | (3 sets X 12 reps) | (3 sets X 10 reps) | (3 sets X 10 reps)  | (3 sets X 10 reps) | (3 sets X 8 reps)  |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------
    |        Dips        |     Supermans      |     Jump Squats     |        Dips        |     Hammer Curl    |   REST   |  REST  |
    | (3 sets X 10 reps) |  (3 sets X 8 reps) | (3 sets X 10 reps)  | (3 sets X 12 reps) | (3 sets X 10 reps) |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------"""
    ROUTINE_2 = """
    -------------------------------------------------------------------------------------------------------------------------------
    |//////////////////////////////////////////////////////////GYM PROGRAM////////////////////////////////////////////////////////|
    -------------------------------------------------------------------------------------------------------------------------------
    |       MONDAY       |      TUESDAY       |      WEDNESDAY      |      THRUSDAY      |       FRIDAY       | SATURDAY | SUNDAY |      
    ------------------------------------------------------------------------------------------------------------------------------
    |    Bench Press     |      Deadlift      |   Barbell Squads    |    Barbell Press   |      Chin Ups      |   REST   |  REST  |
    | (4 sets X 10 reps) | (4 sets X 10 reps) | (4 sets X 12 reps)  | (4 sets X 10 reps) | (4 sets X 10 reps) |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------
    |      Pec Fly       |     Dumbbell Row   |   Forward Lunges    | Side Lateral Raises|     Bicep Curl     |   REST   |  REST  |
    | (4 sets X 12 reps) | (4 sets X 10 reps) | (4 sets X 10 reps)  | (4 sets X 10 reps) | (4 sets X 8 reps)  |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------
    |        Dips        |      Pull Ups      |     Jump Squats     |    Front Raises    |     Hammer Curl    |   REST   |  REST  |
    | (4 sets X 10 reps) |  (4 sets X 8 reps) | (4 sets X 10 reps)  | (4 sets X 12 reps) | (4 sets X 10 reps) |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------
    |      Push Ups      |    Dumbbell Curl   |     Globet Squat    |    Upright Row     |    Skullcrusher    |   REST   |  REST  |
    | (4 sets X 10 reps) |  (4 sets X 8 reps) | (4 sets X 10 reps)  | (4 sets X 12 reps) | (4 sets X 10 reps) |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------
    |      Pushdown      |     Hammer Curl    |  Extensions Squats  |     Face Pull      |        Dips        |   REST   |  REST  |
    | (4 sets X 10 reps) |  (4 sets X 8 reps) | (4 sets X 10 reps)  | (4 sets X 12 reps) | (4 sets X 10 reps) |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------"""
    ROUTINE_3 = """
    -------------------------------------------------------------------------------------------------------------------------------
    |//////////////////////////////////////////////////////////GYM PROGRAM////////////////////////////////////////////////////////|
    -------------------------------------------------------------------------------------------------------------------------------
    |       MONDAY       |      TUESDAY       |      WEDNESDAY      |      THRUSDAY      |       FRIDAY       | SATURDAY | SUNDAY |      
    ------------------------------------------------------------------------------------------------------------------------------
    |    Bench Press     |      Deadlift      |   Barbell Squads    |    Barbell Press   |      Chin Ups      |   REST   |  REST  |
    | (4 sets X 12 reps) | (4 sets X 12 reps) | (4 sets X 12 reps)  | (4 sets X 12 reps) | (4 sets X 12 reps) |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------
    |      Pec Fly       |     Dumbbell Row   |   Forward Lunges    | Side Lateral Raises|     Bicep Curl     |   REST   |  REST  |
    | (4 sets X 12 reps) | (4 sets X 12 reps) | (4 sets X 12 reps)  | (4 sets X 12 reps) | (4 sets X 12 reps) |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------
    |        Dips        |      Pull Ups      |     Calve Raise     |    Front Raises    |     Hammer Curl    |   REST   |  REST  |
    | (4 sets X 12 reps) | (4 sets X 12 reps) | (4 sets X 12 reps)  | (4 sets X 12 reps) | (4 sets X 12 reps) |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------
    |      Push Ups      |    Barbell Curl    |     Globet Squat    |    Upright Row     |    Skullcrusher    |   REST   |  REST  |
    | (4 sets X 12 reps) | (4 sets X 12 reps) | (4 sets X 12 reps)  | (4 sets X 12 reps) | (4 sets X 12 reps) |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------
    |      Pushdown      |     Hammer Curl    |  Extensions Squats  |     Face Pull      |        Dips        |   REST   |  REST  |
    | (4 sets X 12 reps) | (4 sets X 12 reps) | (4 sets X 12 reps)  | (4 sets X 12 reps) | (4 sets X 12 reps) |   REST   |  REST  |
    -------------------------------------------------------------------------------------------------------------------------------"""
    question_8 = input("Answer with the following options 'B' for Beginner, 'I' for Intermediate and 'A' for Advanced: ")
    if question_8 == 'B' or question_8 == 'b':
        print(ROUTINE_1)
    if question_8 == 'I' or question_8 == 'i':
        print(ROUTINE_2)
    if question_8 == 'A' or question_8 == 'a':
        print(ROUTINE_3)

if __name__ == "__main__":
    while True:
        print()
        print(MENU)
        option = acceptOption()
        runOption(option)
        if option == QUIT:
            print("Have a nice day! Thank you for your visit! Come back soon")
            break
# Out:
# Please enter your full name:  Adrian
# Hi Adrian ! WELCOME TO MY GYM PROGRAM!
# Are you ready? yes
# LET'S GO!
#
# ...
#                                                             GYM PROGRAM
#                                                       Start Your New Lifestyle
# ...
#
#
# I am Adrian Renato Perez Galindo, and this is my first project for Computer Programming, using Python.
# Before we begin, I would like to mention that I chose the "GYM" theme for my program because it is an
# activity I personally enjoy and like to talk about. For this reason, I decided to create software that
# uses different operators and functions to build a graphical user interface. In other words, it is a
# program where I, as the developer, can provide information to users, allowing them to easily interact with it.
#
# With this brief introduction, we can begin this journey...
#
# Please, perform the following steps/options to make the evaluation in the best possible way.
#
#
# ...
